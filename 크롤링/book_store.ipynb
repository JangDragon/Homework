# %%
# !python.exe -m pip install --upgrade pip

# %%
# !pip install selenium
# !pip install chromedriver_autoinstaller
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.2-cp310-cp310-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.2-cp310-cp310-win_amd64.whl (11.6 MB)
# Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...

# %%
# !python -m pip install "pymongo[srv]"==3.11

# %%
import chromedriver_autoinstaller
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
from pymongo import MongoClient
from IPython.display import HTML
import pandas as pd

# %%
def listAppend(img_src, title, author, publish, created, price, sales_num = 'x'):
    img_list.append(img_src)
    title_list.append(title)
    author_list.append(author)
    publish_list.append(publish)
    created_list.append(created)
    price_list.append(price)
    sales_num_list.append(sales_num)
    return True

# %% [markdown]
# ## yes24

# %%
def yes24(keyword):
    driver = webdriver.Chrome()
    url = f'https://www.yes24.com/Product/Search?domain=ALL&query={keyword}'
    driver.get(url)
    
    for i in range(20):
        driver.execute_script(f'window.scrollTo(0, document.body.scrollHeight / 20 * {i})')
        time.sleep(0.1)

    li_elements_xpath = '/html/body/div[1]/div[4]/div/div[2]/section[2]/div[3]/ul/li'
    li_elements = driver.find_elements(By.XPATH, li_elements_xpath)
    
    for li in li_elements:
        try:
            img = li.find_element(By.TAG_NAME, 'img')
            title = li.find_element(By.CLASS_NAME,'gd_name')
            author = li.find_element(By.CLASS_NAME, 'info_auth').text.split(' 저')[0]
            publish = li.find_element(By.CLASS_NAME, 'info_pub').text
            created = li.find_element(By.CLASS_NAME, 'info_date').text
            price = li.find_element(By.CLASS_NAME, 'yes_b').text
            sales_num = li.find_elements(By.CLASS_NAME, 'saleNum')
            if sales_num:
                sales_num = sales_num[0].text.split(' ')[1]
            else:
                sales_num = '0'
            
            title = img.get_attribute('alt')
            img_src = img.get_attribute('src')
            listAppend(img_src, title, author, publish, created, price, sales_num)
            
        except:
            print('오류')
            continue  # 이미지가 없는 경우 건너뜀

# %%
yes24('python')
# Out:
# https://image.yes24.com/goods/119293186/L
# Do it! 점프 투 파이썬
# 박응용 저
# 이지스퍼블리싱
# 2023년 06월
# 19,800원
# 69,096
# https://image.yes24.com/goods/126158046/L
# 데이터에듀 빅데이터 분석기사 실기 with Python
# 윤종식 저
# 데이터에듀
# 2024년 05월
# 26,100원
# 3,942
# https://image.yes24.com/goods/125905685/L
# OpenAI API와 파이썬으로 나만의 챗GPT 만들기
# 후루카와 쇼이치, 오기와라 유이 저/최용 역
# 위키북스
# 2024년 04월
# 21,600원
# 3,801
# https://image.yes24.com/goods/125231887/L
# 2024 빅데이터분석기사 실기 한권완성 [파이썬(Python)]
# 최예신, 박진원, 이경숙, 김주현 저
# 예문에듀
# 2024년 05월
# 27,000원
# 3,306
# https://image.yes24.com/goods/126437780/L
# 챗GPT와 파이썬으로 주식 자동매매 앱 및 웹 투자 리포트 만들기
# 박찬의 저
# 앤써북
# 2024년 05월
# 15,120원
# 2,316
# https://image.yes24.com/goods/109625396/L
# 혼자 공부하는 파이썬
# 윤인성 저
# 한빛미디어
# 2022년 06월
# 19,800원
# 37,887
# https://image.yes24.com/goods/126158349/L
# 이미지 처리 바이블
# 류태선, 콥스랩 연구원 저
# 길벗
# 2024년 04월
# 39,600원
# 2,886
# https://image.yes24.com/goods/96024871/L
# 혼자 공부하는 머신러닝+딥러닝
# 박해선 저
# 한빛미디어
# 2020년 12월
# 23,400원
# 35,727
# ...

# %% [markdown]
# ## 인터파크도서

# %%
def interpark(keyword):
    driver = webdriver.Chrome()
    url = f'https://bsearch.interpark.com/dsearch/book.jsp?sch=all&query={keyword}'
    driver.get(url)
    
    for i in range(20):
        driver.execute_script(f'window.scrollTo(0, document.body.scrollHeight / 20 * {i})')
        time.sleep(0.1)
    
    li_elements_xpath = '/html/body/div[3]/div[2]/span[1]/form'
    li_elements = driver.find_elements(By.CLASS_NAME, 'list_wrap')
        
    for li in li_elements:
        try:
            img = li.find_element(By.CLASS_NAME, 'bd')
            title = li.find_element(By.TAG_NAME,'b')
            w_list = li.find_element(By.CLASS_NAME, 'writer').text.split(' 저')
            elements = li.find_elements(By.CLASS_NAME, 'nowMoney')
            if elements:
                price = elements[0].text.split('원')[0]
            else:
                price = li.find_element(By.CLASS_NAME, 'defaultNum').text.split('원')[0]
            sales_num = li.find_elements(By.CLASS_NAME, 'saleIndex')
            if sales_num:
                sales_num = sales_num[0].text.split(' ')[1] # 판매지수
            else:
                sales_num = '0'
    
            img_src = img.get_attribute('src')
            title = title.text
            if len(w_list)!=1:
                author = w_list[0]
                publish = w_list[1].split('I')[-2]
                created = w_list[1].split('I')[-1]
            else:
                author = 'X'
                publish = w_list[0].split('I')[-2]
                created = w_list[0].split('I')[-1]
                
            listAppend(img_src, title, author, publish, created, price, sales_num)
            
        except:
            print('오류')
            continue  # 이미지가 없는 경우 건너뜀

# %%
interpark('python')
# Out:
# https://qi-b.qoo10cdn.com/partner/goods_image/4/0/0/3/356824003h.jpg
# 2024 이기적 빅데이터분석기사 실기 기본서 Python 분석
# 나홍석, 배원성, 이건길, 이혜영, 고려사이버대학교 AI·빅데이터 연구소
# 영진닷컴
# 2023.11.13
# 22,500원
# 683
# https://qi-b.qoo10cdn.com/partner/goods_image/1/5/0/5/356881505h.jpg
# 2024 빅데이터분석기사 실기 한권완성: 파이썬(Python)
# 최예신, 박진원, 이경숙, 김주현
# 예문에듀
# 2024.05.20
# 27,000원
# 315
# https://qi-b.qoo10cdn.com/partner/goods_image/0/4/4/3/356880443h.jpg
# Python으로 학습하는 컴퓨터 알고리즘
# X
# 홍릉
# 2024.02.23
# 22,000원
# 24
# https://qi-b.qoo10cdn.com/partner/goods_image/3/2/3/9/356893239h.jpg
# R과 Python을 활용한 통계계산
# 허명회
# 자유아카데미
# 2024.03.29
# 20,000원
# 0
# https://qi-b.qoo10cdn.com/partner/goods_image/5/6/8/9/356895689h.jpg
# 처음 만나는 통계와 데이터분석: R과 Python 활용
# 윤정연
# 한국금융연수원
# 2024.04.01
# 20,790원
# 0
# https://qi-b.qoo10cdn.com/partner/goods_image/9/8/3/1/345299831h.jpg
# 알파(R과 Python)를 활용한 인공지능 챗봇 14
# 황윤찬
# STORYJOA(스토리조아)
# 2020.12.30
# 20,700원
# 10
# https://qi-b.qoo10cdn.com/partner/goods_image/0/6/3/4/354820634h.jpg
# ...

# %% [markdown]
# ## 알라딘

# %%
def aladin(keyword):
    driver = webdriver.Chrome()
    keyword = 'python'
    url = f'https://www.aladin.co.kr/m/msearch.aspx?SearchWord={keyword}&SearchTarget=All'
    driver.get(url)
    
    for i in range(20):
        driver.execute_script(f'window.scrollTo(0, document.body.scrollHeight / 20 * {i})')
        time.sleep(0.1)
    
    li_elements_xpath = '/html/body/div[12]'
    li_elements = driver.find_elements(By.CLASS_NAME, 'browse_list_box')
        
    for li in li_elements:
        try:
            img = li.find_elements(By.CLASS_NAME, 'front_cover')
            if img:
                img_src = img[0].get_attribute('src')
            else:
                img_src = li.find_element(By.CLASS_NAME, 'i_cover').get_attribute('src')
                
            title = li.find_element(By.CLASS_NAME,'b_book_t').text.split('] ')[1]
            author = li.find_elements(By.TAG_NAME, 'li')[1].text.split(' (지은이)')[0]
            
            elements = li.find_elements(By.TAG_NAME, 'li')[2].text
            publish = elements.split(' | ')[0]
            created = elements.split(' | ')[1]
    
            price = li.find_element(By.CLASS_NAME, 'b_price').text
            sales_num = 'x'
                
            listAppend(img_src, title, author, publish, created, price, sales_num)
        except:
            print('오류')
            continue  # 이미지가 없는 경우 건너뜀

# %%
aladin('python')
# Out:
# https://image.aladin.co.kr/product/33535/33/cover200/k902939678_1.jpg
# 2024 빅데이터분석기사 실기 한권완성 [파이썬(Python)]
# 최예신, 박진원, 이경숙, 김주현
# 예문에듀
# 2024년 05월
# 27,000원
# https://image.aladin.co.kr/product/33849/91/cover200/k512930108_1.jpg
# 데이터에듀 빅데이터 분석기사 실기 with Python
# 윤종식
# 데이터에듀
# 2024년 05월
# 26,100원
# https://image.aladin.co.kr/product/32848/94/cover200/8931467680_1.jpg
# 2024 이기적 빅데이터분석기사 실기 (Python 분석)
# 나홍석, 배원성, 이건길, 이혜영, 고려사이버대학교 AI.빅데이터 연구소
# 영진.com(영진닷컴)
# 2023년 11월
# 22,500원
# https://image.aladin.co.kr/product/33840/10/cover200/k822930996_1.jpg
# 인과관계 추론과 발견 with Python
# Aleksander Molak
# 홍릉(홍릉과학출판사)
# 2024년 04월
# 37,000원
# https://image.aladin.co.kr/product/25432/17/cover200/k552633414_1.jpg
# Effective Python 2nd 이펙티브 파이썬 : 파이썬 코딩의 기술
# 브렛 슬라킨
# 길벗
# 2020년 10월
# 28,800원
# https://image.aladin.co.kr/product/33839/86/cover200/k032930996_1.jpg
# 3D 딥러닝 with python
# Xudong Ma, Vishakh Hegde, Lilit Yolyan
# 홍릉(홍릉과학출판사)
# 2024년 04월
# 29,000원
# ...

# %%
def search(num):
    url = 'mongodb+srv://mnbv7952:hXHFetjGCo06jkTn@cluster0.marjbqu.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'
    client = MongoClient(url)
    database = client['bookstore']
    word = input("검색어 입력: ")

    if num =='1':
        collection = database['yes24']
        yes24(word)
    elif num=='2':
        collection = database['interpark']
        interpark(word)
    elif num=='3':
        collection = database['aladin']
        aladin(word)

    books_insert = []
    print(len(img_list))
    for i in range(len(img_list)):
        books_insert.append({
            '이미지':img_list[i],
            '책이름':title_list[i],
            '저자':author_list[i],
            '출판사':publish_list[i],
            '출시일':created_list[i],
            '가격':price_list[i],
            '판매수':sales_num_list[i]
        })
    result = collection.insert_many(books_insert)

# %%
collection = ''
img_list = []
title_list = []
author_list = []
publish_list = []
created_list = []
price_list = []
sales_num_list = []

# %%
def start():
    print('1.yes24 | 2.interpark | 3.aladin')
    num = input("사이트 선택: ")
    search(num)
    dataTot = []
    for i in range(len(img_list)):
        url = img_list[i]
        name = title_list[i]
        author = author_list[i]
        publisher = publish_list[i]
        publicationDate = created_list[i]
        price = price_list[i]
        sales_num = sales_num_list[i]
        dataTot.append([url, name, author, publisher, publicationDate, price, sales_num])

    col = ["이미지", "이름", "저자", "출판사", "출판일", "가격", "판매량"]
    df = pd.DataFrame(data=dataTot, columns=col)
    # ▲ 데이터프레임으로 저장

    def image_html(url):
        return '<img src="' + url + '" width="100">'
    # ▲ 이미지를 HTML태그로 변환하는 함
    
    df["이미지"] = df["이미지"].apply(image_html)
    # ▲ HTML 태그 적용
    
    show = display(HTML(df.to_html(escape=False)))
    # ▲ HTML로 랜더링 되도록 설정? < 이 부분을 잘 모르겠음.
    
    return show

# %%
start()
# Out:
# 1.yes24 | 2.interpark | 3.aladin
# 사이트 선택:  1
# 검색어 입력:  python
# 24
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>이미지</th>
#       <th>이름</th>
#       <th>저자</th>
#       <th>출판사</th>
#       <th>출판일</th>
#       <th>가격</th>
#       <th>판매량</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="https://image.yes24.com/goods/119293186/L" width="100"></td>
#       <td>Do it! 점프 투 파이썬</td>
#       <td>박응용</td>
#       <td>이지스퍼블리싱</td>
#       <td>2023년 06월</td>
#       <td>19,800</td>
#       <td>69,477</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="https://image.yes24.com/goods/126158046/L" width="100"></td>
#       <td>데이터에듀 빅데이터 분석기사 실기 with Python</td>
#       <td>윤종식</td>
#       <td>데이터에듀</td>
#       <td>2024년 05월</td>
#       <td>26,100</td>
#       <td>4,092</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
start()
# Out:
# 1.yes24 | 2.interpark | 3.aladin
# 사이트 선택:  2
# 검색어 입력:  python
# 25
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>이미지</th>
#       <th>이름</th>
#       <th>저자</th>
#       <th>출판사</th>
#       <th>출판일</th>
#       <th>가격</th>
#       <th>판매량</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="https://qi-b.qoo10cdn.com/partner/goods_image/4/0/0/3/356824003h.jpg" width="60"></td>
#       <td>2024 이기적 빅데이터분석기사 실기 기본서 Python 분석</td>
#       <td>나홍석, 배원성, 이건길, 이혜영, 고려사이버대학교 AI·빅데이터 연구소</td>
#       <td>영진닷컴</td>
#       <td>2023.11.13</td>
#       <td>22,500</td>
#       <td>676</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="https://qi-b.qoo10cdn.com/partner/goods_image/1/5/0/5/356881505h.jpg" width="60"></td>
#       <td>2024 빅데이터분석기사 실기 한권완성: 파이썬(Python)</td>
#       <td>최예신, 박진원, 이경숙, 김주현</td>
#       <td>예문에듀</td>
#       <td>2024.05.20</td>
# ...

# %%
start()
# Out:
# 1.yes24 | 2.interpark | 3.aladin
# 사이트 선택:  3
# 검색어 입력:  python
# 25
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>이미지</th>
#       <th>이름</th>
#       <th>저자</th>
#       <th>출판사</th>
#       <th>출판일</th>
#       <th>가격</th>
#       <th>판매량</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="https://image.aladin.co.kr/product/33535/33/cover200/k902939678_1.jpg" width="60"></td>
#       <td>2024 빅데이터분석기사 실기 한권완성 [파이썬(Python)]</td>
#       <td>최예신, 박진원, 이경숙, 김주현</td>
#       <td>예문에듀</td>
#       <td>2024년 05월</td>
#       <td>27,000</td>
#       <td>x</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="https://image.aladin.co.kr/product/33849/91/cover200/k512930108_1.jpg" width="60"></td>
#       <td>데이터에듀 빅데이터 분석기사 실기 with Python</td>
#       <td>윤종식</td>
#       <td>데이터에듀</td>
#       <td>2024년 05월</td>
#       <td>26,100</td>
#       <td>x</td>
# ...
